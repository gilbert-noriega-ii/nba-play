# %% [markdown]
# # Some Teams One Dream
# Hand checking NBA teams from the 2014-2018 seasons

# %%
#importing libraries 
import pandas as pd

# %%
#uploading the nba csv and saving it as a dataframe called nba
nba = pd.read_csv('nba.games.stats.csv')

# %%
#sneak peak into the data
nba.head()
# Out:
#    Unnamed: 0 Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0           1  ATL     1  2014-10-29  Away      TOR         L         102
# 1           2  ATL     2  2014-11-01  Home      IND         W         102
# 2           3  ATL     3  2014-11-05  Away      SAS         L          92
# 3           4  ATL     4  2014-11-07  Away      CHO         L         119
# 4           5  ATL     5  2014-11-08  Home      NYK         W         103
#
#    OpponentPoints  FieldGoals  ...  Opp.FreeThrows  Opp.FreeThrowsAttempted  \
# 0             109          40  ...              27                       33
# 1              92          35  ...              18                       21
# 2              94          38  ...              27                       38
# 3             122          43  ...              20                       27
# 4              96          33  ...               8                       11
#
# ...

# %%
#deleting an unnecessary row to the data
#appears to be the prior index
del nba['Unnamed: 0']

# %%
#checking to see how many rows and columns there are
nba.shape
# Out:
# (9840, 40)

# %%
#checking data types, null values, and column names
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Team                      9840 non-null   object
#  1   Game                      9840 non-null   int64
#  2   Date                      9840 non-null   object
#  3   Home                      9840 non-null   object
#  4   Opponent                  9840 non-null   object
#  5   WINorLOSS                 9840 non-null   object
#  6   TeamPoints                9840 non-null   int64
#  7   OpponentPoints            9840 non-null   int64
#  8   FieldGoals                9840 non-null   int64
#  9   FieldGoalsAttempted       9840 non-null   int64
#  10  FieldGoals.               9840 non-null   float64
#  11  X3PointShots              9840 non-null   int64
#  12  X3PointShotsAttempted     9840 non-null   int64
# ...

# %%
#looking at the summary statistics of all the numeric columns
nba.describe().T
# Out:
#                            count        mean        std     min     25%  \
# Game                      9840.0   41.500000  23.670804   1.000  21.000
# TeamPoints                9840.0  103.652337  12.188043  64.000  95.000
# OpponentPoints            9840.0  103.652337  12.188043  64.000  95.000
# FieldGoals                9840.0   38.602439   5.029992  19.000  35.000
# FieldGoalsAttempted       9840.0   84.902439   7.130043  60.000  80.000
# FieldGoals.               9840.0    0.455689   0.054711   0.271   0.418
# X3PointShots              9840.0    9.126829   3.598084   0.000   7.000
# X3PointShotsAttempted     9840.0   25.623679   7.102501   4.000  21.000
# X3PointShots.             9840.0    0.354321   0.097782   0.000   0.290
# FreeThrows                9840.0   17.320630   6.002620   1.000  13.000
# FreeThrowsAttempted       9840.0   22.749390   7.390451   1.000  18.000
# FreeThrows.               9840.0    0.762395   0.104297   0.143   0.696
# ...

# %%
#confirming the deleted column
nba
# Out:
#      Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0     ATL     1  2014-10-29  Away      TOR         L         102
# 1     ATL     2  2014-11-01  Home      IND         W         102
# 2     ATL     3  2014-11-05  Away      SAS         L          92
# 3     ATL     4  2014-11-07  Away      CHO         L         119
# 4     ATL     5  2014-11-08  Home      NYK         W         103
# ...   ...   ...         ...   ...      ...       ...         ...
# 9835  WAS    78  2018-04-03  Away      HOU         L         104
# 9836  WAS    79  2018-04-05  Away      CLE         L         115
# 9837  WAS    80  2018-04-06  Home      ATL         L          97
# 9838  WAS    81  2018-04-10  Home      BOS         W         113
# 9839  WAS    82  2018-04-11  Away      ORL         L          92
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.FreeThrows  \
# 0                109          40                   80  ...              27
# ...

# %% [markdown]
# - season one w/l column

# %%
nba14_15 = nba.loc[:2459,:]

# %%
nba15_16 = nba.loc[2460:4919,:]

# %%
nba16_17 = nba.loc[4920:7379,:]

# %%
nba17_18 = nba.loc[7380:,:]

# %%
west14_15 = nba14_15[nba14_15.Team.isin(['LAL', 'LAC', 'DEN', 'HOU', 'OKC', 'UTA', 'DAL', 'POR', 'MEM', 'PHO', 'SAS', 'SAC', 'NOP', 'MIN', 'GSW'])]

# %% [markdown]
# - western conference
#     - Los Angeles Lakers or LAL
#     - Los Angeles Clippers or LAC
#     - Denver Nuggets or DEN
#     - Houston Rockets or HOU
#     - Oklahoma City Thunder or OKC
#     - Utah Jazz or UTA
#     - Dallas Mavericks or DAL
#     - Portland Trail Blazers or POR
#     - Memphis Grizzlies or MEM
#     - Phoenix Suns or PHO
#     - San Antonio Spurs or SAS
#     - Sacramento Kings or SAC
#     - New Orleans Pelicans or NOP
#     - Minnesota Timberwolves or MIN
#     - Golden State Warriors or GSW

# %%
west14_15
# Out:
#      Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 492   DAL     1  2014-10-28  Away      SAS         L         100
# 493   DAL     2  2014-10-30  Home      UTA         W         120
# 494   DAL     3  2014-11-01  Away      NOP         W         109
# 495   DAL     4  2014-11-03  Home      BOS         W         118
# 496   DAL     5  2014-11-06  Away      POR         L          87
# ...   ...   ...         ...   ...      ...       ...         ...
# 2373  UTA    78  2015-04-08  Home      SAC         W         103
# 2374  UTA    79  2015-04-10  Home      MEM         L          88
# 2375  UTA    80  2015-04-11  Away      POR         W         111
# 2376  UTA    81  2015-04-13  Home      DAL         W         109
# 2377  UTA    82  2015-04-15  Away      HOU         L          91
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.FreeThrows  \
# 492              101          38                   78  ...              13
# ...

# %%
east14_15 = nba14_15[nba14_15.Team.isin(['MIL', 'TOR', 'BOS', 'IND', 'MIA', 'PHI', 'BRK', 'ORL', 'WAS', 'CHO', 'CHI', 'NYK', 'DET', 'ATL', 'CLE'])]

# %%
east14_15
# Out:
#      Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0     ATL     1  2014-10-29  Away      TOR         L         102
# 1     ATL     2  2014-11-01  Home      IND         W         102
# 2     ATL     3  2014-11-05  Away      SAS         L          92
# 3     ATL     4  2014-11-07  Away      CHO         L         119
# 4     ATL     5  2014-11-08  Home      NYK         W         103
# ...   ...   ...         ...   ...      ...       ...         ...
# 2455  WAS    78  2015-04-08  Away      PHI         W         119
# 2456  WAS    79  2015-04-10  Away      BRK         L          80
# 2457  WAS    80  2015-04-12  Home      ATL         W         108
# 2458  WAS    81  2015-04-14  Away      IND         L          95
# 2459  WAS    82  2015-04-15  Away      CLE         L         108
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.FreeThrows  \
# 0                109          40                   80  ...              27
# ...

# %% [markdown]
# - eastern conference
#     - Milwaukee Bucks as MIL
#     - Toronto Raptors as TOR
#     - Boston Celtics as BOS
#     - Indiana Pacers as IND
#     - Miami Heat as MIA
#     - Philadelphia as PHI
#     - Brooklyn Nets as BRK
#     - Orlando Magic as ORL
#     - Washington Wizards as WAS
#     - Charlotte Hornets as CHO
#     - Chicago Bulls as CHI
#     - New York Knicks as NYK
#     - Detroit Pistons as DET
#     - Atlanta Hawks as ATL
#     - Cleveland Cavaliers as CLE
